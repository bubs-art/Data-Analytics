# %% [markdown]
# <a href="https://colab.research.google.com/github/bubs-art/Data-Analytics/blob/main/matplotlib_mini_proj_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Global Temperature Trends
'''Tasks:
- Plot a line graph showing global temperature changes over decades.
- Create a heatmap of temperature variations by country.
- Compare average temperatures across different continents.
- Visualize seasonal temperature fluctuations using a box plot.'''

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

gtl = pd.read_csv("/content/GlobalLandTemperaturesByCountry.csv")
g = gtl.dropna()

g['dt'] = pd.to_datetime(data['dt'])
g['year'] = g['dt'].dt.year
y= g.groupby('year')['AverageTemperature'].mean()
plt.figure(figsize=(20, 5))
plt.plot(y.index, y.values)
plt.title('Global Temperature Changes Over Years')
plt.xlabel('Year')
plt.ylabel('Average Temperature')
xticks = range(1744, y.index.max() + 1, 11)
plt.xticks(xticks)
plt.show()
#2
'''country_temps = g.groupby('Country')['AverageTemperature'].mean()

plt.figure(figsize=(10,20))
sns.heatmap(country_temps)
plt.show()
'''


#3
avg = g.groupby("Country")["AverageTemperature"].mean()
plt.figure(figsize=(50,10))
avg.plot(kind = 'bar')

#4
g['month'] = g['dt'].dt.month
plt.figure(figsize=(10,10))
sns.boxplot(data=g, x='month', y='AverageTemperature')
plt.title('Trend of Seasonal Temperatures')
plt.xlabel('Month')
plt.ylabel('detected temperature')
plt.xticks(ticks=range(12), labels=["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"])
plt.show()
