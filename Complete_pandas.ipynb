# %% [markdown]
# <a href="https://colab.research.google.com/github/bubs-art/Data-Analytics/blob/main/Complete_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing all libraries required**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=["A","B","C"])

# %%
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.columns.tolist()
# Out:
# ['A', 'B', 'C']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.index.tolist()
# Out:
# [0, 1, 2]

# %%
df=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],columns=["A","B","C"],index=["x","y","z"])

# %%
df.head()
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
coffee=pd.read_csv("/content/coffee.csv")

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
bios=pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv")
results=pd.read_parquet("/content/results.parquet")

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.head(10)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
coffee.tail(10)
# Out:
#           Day Coffee Type  Units Sold
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.sample(10)
# Out:
#           Day Coffee Type  Units Sold
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 10   Saturday    Espresso          45
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 1      Monday       Latte          15
# 4   Wednesday    Espresso          35
# 0      Monday    Espresso          25

# %%
#coffee.loc[#Rows,#Columns]

# %%
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[[0,1,5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
coffee.loc[0:3]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
coffee.loc[5:]
# Out:
#           Day Coffee Type  Units Sold
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[0:3,["Day"]]
# Out:
#        Day
# 0   Monday
# 1   Monday
# 2  Tuesday
# 3  Tuesday

# %%
coffee.loc[:,["Day","Units Sold"]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
coffee.iloc[:,[0,2]]
# Out:
#           Day  Units Sold
# 0      Monday          25
# 1      Monday          15
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45
# 11   Saturday          35
# 12     Sunday          45
# 13     Sunday          35

# %%
#coffee.iloc[#Row,#column(index)]

# %%
coffee.loc[1,"Units Sold"]=10

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# To access only one value this can also be used

coffee.at[0,"Units Sold"]
# Out:
# 25

# %%
coffee.Day
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee["Day"]
# Out:
# 0        Monday
# 1        Monday
# 2       Tuesday
# 3       Tuesday
# 4     Wednesday
# 5     Wednesday
# 6      Thursday
# 7      Thursday
# 8        Friday
# 9        Friday
# 10     Saturday
# 11     Saturday
# 12       Sunday
# 13       Sunday
# Name: Day, dtype: object

# %%
coffee.sort_values("Units Sold")
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          10
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
coffee.sort_values("Units Sold",ascending=False)
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          10

# %%
for index,row in coffee.iterrows():
  print(index)
  print(row)
  print("\n\n\n\n\n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         10
# Name: 1, dtype: object
#
#
#
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
#
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
#
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
#
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
#
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
#
#
#
# 8
# Day              Friday
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
bios.loc[bios['height_cm']>215]
# Out:
#         athlete_id                   name   born_date               born_city  \
# 5089          5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5583          5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5673          5696         Gunther Behnke  1963-01-19              Leverkusen
# 5716          5739               Uwe Blab  1962-03-26        München (Munich)
# 5781          5804         Tommy Burleson  1952-02-24               Crossnore
# 5796          5819          Andy Campbell  1956-07-21               Melbourne
# 6223          6250            Lars Hansen  1954-09-27  København (Copenhagen)
# 6270          6298            Hu Zhangbao  1963-04-05                     NaN
# 6409          6440       Sergey Kovalenko  1947-08-11                     NaN
# 6420          6451          Jānis Krūmiņš  1930-01-30                   Cēsis
# 6504          6537            Luc Longley  1969-01-19               Melbourne
# ...

# %%
bios.loc[bios["height_cm"]>215,['name','height_cm']]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# ...

# %%
bios.loc[(bios["height_cm"]>215) & (bios['born_country']=='USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios.loc[bios['born_country']=='IND',['height_cm','name']]
# Out:
#         height_cm                name
# 80            NaN      George Caridia
# 101           NaN  Algernon Kingscote
# 270           NaN         Nora Polley
# 273         180.0         Zeeshan Ali
# 274         185.0      Anand Amritraj
# ...           ...                 ...
# 140286        NaN       Bajrang Punia
# 140287        NaN        Deepak Punia
# 143996        NaN         Sumit Nagal
# 144114      174.0        Diksha Dagar
# 144757        NaN           Arif Khan
#
# [536 rows x 2 columns]

# %%
india=bios.loc[(bios['height_cm']>190)& (bios['born_country']=='IND')]

# %%
india.sort_values("height_cm",ascending=False)
# Out:
#         athlete_id                      name   born_date         born_city  \
# 70860        71391             Praveen Kumar  1947-12-06           Sirhali
# 131636      134452              Kynan Chenai  1991-01-29         Hyderabad
# 23226        23402               Rolf Edling  1943-11-30            Mumbai
# 119641      121467  Om Prakash Singh Karhana  1987-01-11           Gurgaon
# 106957      108073    Palwinder Singh Cheema  1982-11-11           Patiala
# 275            276            Vijay Amritraj  1953-12-14  Chennai (Madras)
# 131629      134444        Rupinder Pal Singh  1990-11-11          Faridkot
# 58279        58693    Harishchandra Birajdar  1950-06-05         Nilangana
# 58301        58715               Chandgi Ram  1937-11-09             Sisar
# 103815      104809     Manavjit Singh Sandhu  1976-11-03          Amritsar
# 140265      143768               Udayan Mane  1991-02-24  Chennai (Madras)
# ...

# %%
bios[bios['name'].str.contains("Gagan")]
# Out:
#         athlete_id              name   born_date              born_city  \
# 90981        91707  Gagan Ajit Singh  1980-12-09               Firozpur
# 103778      104771      Gagan Narang  1983-05-06       Chennai (Madras)
# 118985      120764   Gagan Ullalmath  1992-01-08  Bengaluru (Bangalore)
#
#        born_region born_country    NOC  height_cm  weight_kg died_date
# 90981       Punjab          IND  India      177.0       80.0       NaN
# 103778  Tamil Nadu          IND  India      180.0      115.0       NaN
# 118985   Karnataka          IND  India        NaN        NaN       NaN

# %%
bios.query('born_country=="USA"')
# Out:
#         athlete_id               name   born_date         born_city  \
# 54              55      Monique Javer  1967-07-22        Burlingame
# 960            964   Xóchitl Escobedo  1968-09-17       West Covina
# 961            965  Angélica Gavaldón  1973-10-03         El Centro
# 1231          1238     Bert Schneider  1897-07-01         Cleveland
# 1345          1352         Laura Berg  1975-01-06  Santa Fe Springs
# ...            ...                ...         ...               ...
# 145445      149168     Kristen Santos  1994-11-02         Fairfield
# 145446      149169   Corinne Stoddard  2001-08-15           Seattle
# 145454      149180      Anna Hoffmann  2000-03-28           Madison
# 145457      149183     Alix Wilkinson  2000-08-02     Mammoth Lakes
# 145468      149195  Justin Abdelkader  1987-02-25          Muskegon
#
#         born_region born_country            NOC  height_cm  weight_kg  \
# 54       California          USA  Great Britain      177.0       64.0
# ...

# %%
bios.query('born_country=="IND"')
# Out:
#         athlete_id                name   born_date              born_city  \
# 80              81      George Caridia  1869-02-20     Kolkata (Calcutta)
# 101            102  Algernon Kingscote  1888-02-03  Bengaluru (Bangalore)
# 270            271         Nora Polley  1894-07-29                 Budaun
# 273            274         Zeeshan Ali  1970-01-01     Kolkata (Calcutta)
# 274            275      Anand Amritraj  1952-03-20       Chennai (Madras)
# ...            ...                 ...         ...                    ...
# 140286      143790       Bajrang Punia  1994-02-26                 Khudan
# 140287      143791        Deepak Punia  1999-05-19                Jhajjar
# 143996      147660         Sumit Nagal  1997-08-16                Jhajjar
# 144114      147784        Diksha Dagar  2000-12-14                Jhajjar
# 144757      148458           Arif Khan  1990-03-09                Gulmarg
#
#               born_region born_country            NOC  height_cm  weight_kg  \
# ...

# %%
all_india=bios.loc[bios['born_country']=="IND"]

# %%
all_india['height_cm'].mean()
# Out:
# 172.524064171123

# %%
bios.query('born_country=="IND" and born_city=="Kolkata (Calcutta)"')
# Out:
#         athlete_id              name   born_date           born_city  \
# 80              81    George Caridia  1869-02-20  Kolkata (Calcutta)
# 273            274       Zeeshan Ali  1970-01-01  Kolkata (Calcutta)
# 286            287      Leander Paes  1973-06-17  Kolkata (Calcutta)
# 3863          3876       Mac Joachim  1925-01-01  Kolkata (Calcutta)
# 3867          3880    Sakti Mazumdar  1931-11-13  Kolkata (Calcutta)
# 3872          3885    Johnny Nuttall  1919-04-11  Kolkata (Calcutta)
# 9738          9793   Alistair Wilson  1939-08-20  Kolkata (Calcutta)
# 17665        17786  Derrick Anderson  1936-06-20  Kolkata (Calcutta)
# 17809        17930    Neville Lytton  1879-02-06  Kolkata (Calcutta)
# 18017        18138   Margaret Abbott  1876-06-15  Kolkata (Calcutta)
# 18200        18321      Alan Raphael  1931-12-26  Kolkata (Calcutta)
# 19029        19162     Meldric daLuz  1921-02-01  Kolkata (Calcutta)
# 25627        25819      Nikhil Nandy  1932-01-01  Kolkata (Calcutta)
# ...

# %%
coffee['price']=60

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price
# 0     Monday    Espresso          25     60
# 1     Monday       Latte          10     60
# 2    Tuesday    Espresso          30     60
# 3    Tuesday       Latte          20     60
# 4  Wednesday    Espresso          35     60

# %%
coffee['new_price']=np.where(coffee['Coffee Type']=='Espresso',50,70)

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  new_price
# 0     Monday    Espresso          25     60         50
# 1     Monday       Latte          10     60         70
# 2    Tuesday    Espresso          30     60         50
# 3    Tuesday       Latte          20     60         70
# 4  Wednesday    Espresso          35     60         50

# %%
coffee.drop(columns=['price'],inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25         50
# 1      Monday       Latte          10         70
# 2     Tuesday    Espresso          30         50
# 3     Tuesday       Latte          20         70
# 4   Wednesday    Espresso          35         50
# 5   Wednesday       Latte          25         70
# 6    Thursday    Espresso          40         50
# 7    Thursday       Latte          30         70
# 8      Friday    Espresso          45         50
# 9      Friday       Latte          35         70
# 10   Saturday    Espresso          45         50
# 11   Saturday       Latte          35         70
# 12     Sunday    Espresso          45         50
# 13     Sunday       Latte          35         70

# %%
coffee['revenue']=coffee['Units Sold']*coffee['new_price']

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  new_price  revenue
# 0     Monday    Espresso          25         50     1250
# 1     Monday       Latte          10         70      700
# 2    Tuesday    Espresso          30         50     1500
# 3    Tuesday       Latte          20         70     1400
# 4  Wednesday    Espresso          35         50     1750

# %%
coffee.rename(columns={'new_price':'price'},inplace=True)

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios_new=bios.copy()

# %%
bios_new['first_name']=bios_new['name'].str.split(" ").str[0]

# %%
bios_new.query('first_name=="Keith"')
# Out:
#         athlete_id               name   born_date     born_city  \
# 1897          1907       Keith Hanlon  1966-09-01           NaN
# 3505          3517      Keith Wallace  1961-03-29       Preston
# 6228          6255      Keith Hartley  1940-10-15     Vancouver
# 8898          8946        Keith Mwila  1966-01-01           NaN
# 12053        12118       Keith Hervey  1898-11-03        Fulham
# ...            ...                ...         ...           ...
# 99921       100722       Keith Carney  1970-02-03    Providence
# 102227      103168      Keith Beavers  1983-02-09        London
# 109900      111105  Keith Cumberpatch  1927-08-25  Christchurch
# 115973      117348    Keith Sanderson  1975-02-02      Plymouth
# 122121      124176     Keith Ferguson  1979-09-07          Sale
#
#              born_region born_country            NOC  height_cm  weight_kg  \
# 1897                 NaN          NaN        Ireland        NaN        NaN
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  first_name    145500 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 12.2+ MB

# %%
bios_new['born_datetime']=pd.to_datetime(bios_new['born_date'])

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name born_datetime
# 0  1960-10-02  Jean-François    1886-12-12
# 1         NaN         Arnaud    1969-04-01
# 2  1994-07-17           Jean    1898-08-13
# ...

# %%
bios_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   athlete_id     145500 non-null  int64
#  1   name           145500 non-null  object
#  2   born_date      143693 non-null  object
#  3   born_city      110908 non-null  object
#  4   born_region    110908 non-null  object
#  5   born_country   110908 non-null  object
#  6   NOC            145499 non-null  object
#  7   height_cm      106651 non-null  float64
#  8   weight_kg      102070 non-null  float64
#  9   died_date      33940 non-null   object
#  10  first_name     145500 non-null  object
#  11  born_datetime  143693 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 13.3+ MB

# %%
bios_new['born_year']=bios_new['born_datetime'].dt.year

# %%
bios_new['born_year']
# Out:
# 0         1886.0
# 1         1969.0
# 2         1898.0
# 3         1895.0
# 4         1878.0
#            ...
# 145495    2002.0
# 145496    1999.0
# 145497    1998.0
# 145498    1899.0
# 145499    1913.0
# Name: born_year, Length: 145500, dtype: float64

# %%
bios['height_category']=bios['height_cm'].apply(lambda x:'Short'if x<165 else ('Average'if x < 185 else 'Tall'))

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category
# 0  1960-10-02            Tall
# 1         NaN         Average
# 2  1994-07-17         Average
# 3  1978-03-20         Average
# 4  1930-07-25            Tall

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category
# 0  1960-10-02            Tall
# 1         NaN         Average
# 2  1994-07-17         Average
# 3  1978-03-20         Average
# 4  1930-07-25            Tall

# %%
nocs=pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/noc_regions.csv")

# %%
nocs.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category
# 0  1960-10-02            Tall
# 1         NaN         Average
# 2  1994-07-17         Average
# 3  1978-03-20         Average
# 4  1930-07-25            Tall

# %%
bios=pd.merge(bios,nocs,left_on='born_country',right_on='NOC',how='left')

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category NOC_y  region notes
# 0  1960-10-02            Tall   FRA  France   NaN
# 1         NaN         Average   FRA  France   NaN
# ...

# %%
bios.rename(columns={"region":'born_country_full'},inplace=True)

# %%
usa=bios[bios['born_country']=='USA'].copy()
gbr=bios[bios['born_country']=='GBR'].copy()

# %%
new_df=pd.concat([usa,gbr])

# %%
new_df.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country          NOC_x  height_cm  weight_kg   died_date  \
# 54            USA  Great Britain      177.0       64.0         NaN
# 960           USA         Mexico      170.0       60.0         NaN
# 961           USA         Mexico      160.0       54.0         NaN
# 1231          USA         Canada        NaN        NaN  1986-02-20
# 1345          USA  United States      168.0       61.0         NaN
#
#      height_category NOC_y born_country_full notes
# ...

# %%
new_df.tail()
# Out:
#         athlete_id                name   born_date     born_city born_region  \
# 144811      148512  Benjamin Alexander  1983-05-08        London     England
# 144815      148517       Ashley Watson  1993-10-28  Peterborough     England
# 145005      148716     Peder Kongshaug  2001-08-13     Wimbledon     England
# 145319      149041          Axel Brown  1992-04-02     Harrogate     England
# 145388      149111      Jean-Luc Baker  1993-10-07       Burnley     England
#
#        born_country                NOC_x  height_cm  weight_kg died_date  \
# 144811          GBR              Jamaica        NaN        NaN       NaN
# 144815          GBR              Jamaica        NaN        NaN       NaN
# 145005          GBR               Norway      184.0       86.0       NaN
# 145319          GBR  Trinidad and Tobago        NaN        NaN       NaN
# 145388          GBR        United States        NaN        NaN       NaN
#
#        height_category NOC_y born_country_full notes
# ...

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 0     Monday    Espresso          25     50     1250
# 1     Monday       Latte          10     70      700
# 2    Tuesday    Espresso          30     50     1500
# 3    Tuesday       Latte          20     70     1400
# 4  Wednesday    Espresso          35     50     1750

# %%
coffee.loc[[0,1],'Units Sold']=np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso         NaN     50     1250
# 1      Monday       Latte         NaN     70      700
# 2     Tuesday    Espresso        30.0     50     1500
# 3     Tuesday       Latte        20.0     70     1400
# 4   Wednesday    Espresso        35.0     50     1750
# 5   Wednesday       Latte        25.0     70     1750
# 6    Thursday    Espresso        40.0     50     2000
# 7    Thursday       Latte        30.0     70     2100
# 8      Friday    Espresso        45.0     50     2250
# 9      Friday       Latte        35.0     70     2450
# 10   Saturday    Espresso        45.0     50     2250
# 11   Saturday       Latte        35.0     70     2450
# 12     Sunday    Espresso        45.0     50     2250
# 13     Sunday       Latte        35.0     70     2450

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     2
# price          0
# revenue        0
# dtype: int64

# %%
coffee.fillna(coffee['Units Sold'].mean(),inplace=True)

# %%
coffee.loc[[2,3],'Units Sold']=np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        37.0     50     1250
# 1      Monday       Latte        37.0     70      700
# 2     Tuesday    Espresso         NaN     50     1500
# 3     Tuesday       Latte         NaN     70     1400
# 4   Wednesday    Espresso        35.0     50     1750
# 5   Wednesday       Latte        25.0     70     1750
# 6    Thursday    Espresso        40.0     50     2000
# 7    Thursday       Latte        30.0     70     2100
# 8      Friday    Espresso        45.0     50     2250
# 9      Friday       Latte        35.0     70     2450
# 10   Saturday    Espresso        45.0     50     2250
# 11   Saturday       Latte        35.0     70     2450
# 12     Sunday    Espresso        45.0     50     2250
# 13     Sunday       Latte        35.0     70     2450

# %%
coffee['Units Sold']=coffee['Units Sold'].interpolate()

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 0     Monday    Espresso   37.000000     50     1250
# 1     Monday       Latte   37.000000     70      700
# 2    Tuesday    Espresso   36.333333     50     1500
# 3    Tuesday       Latte   35.666667     70     1400
# 4  Wednesday    Espresso   35.000000     50     1750

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category NOC_y born_country_full notes
# 0  1960-10-02            Tall   FRA            France   NaN
# 1         NaN         Average   FRA            France   NaN
# ...

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Bodrogkisfalud        1
# Ternberg              1
# Klaus                 1
# Plaški                1
# Dulwich Hill          1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country']=="IND"]['born_region'].value_counts()
# Out:
# born_region
# Punjab                                 94
# Maharashtra                            56
# West Bengal                            49
# Haryana                                43
# Uttar Pradesh                          42
# Tamil Nadu                             34
# Karnataka                              32
# National Capital Territory of Delhi    32
# Kerala                                 26
# Andhra Pradesh                         23
# Madhya Pradesh                         22
# Rajasthan                              14
# Manipur                                10
# Himachal Pradesh                       10
# Gujarat                                 9
# Bihar                                   6
# Jharkhand                               5
# Assam                                   5
# Jammu and Kashmir                       5
# Uttarakhand                             4
# Tripura                                 3
# Chandigarh                              2
# ...

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso   37.000000     50     1250
# 1      Monday       Latte   37.000000     70      700
# 2     Tuesday    Espresso   36.333333     50     1500
# 3     Tuesday       Latte   35.666667     70     1400
# 4   Wednesday    Espresso   35.000000     50     1750
# 5   Wednesday       Latte   25.000000     70     1750
# 6    Thursday    Espresso   40.000000     50     2000
# 7    Thursday       Latte   30.000000     70     2100
# 8      Friday    Espresso   45.000000     50     2250
# 9      Friday       Latte   35.000000     70     2450
# 10   Saturday    Espresso   45.000000     50     2250
# 11   Saturday       Latte   35.000000     70     2450
# 12     Sunday    Espresso   45.000000     50     2250
# 13     Sunday       Latte   35.000000     70     2450

# %%
coffee.groupby(['Coffee Type'])['Units Sold'].sum()
# Out:
# Coffee Type
# Espresso    283.333333
# Latte       232.666667
# Name: Units Sold, dtype: float64

# %%
coffee.groupby(['Day'])['revenue'].sum()
# Out:
# Day
# Friday       4700
# Monday       1950
# Saturday     4700
# Sunday       4700
# Thursday     4100
# Tuesday      2900
# Wednesday    3500
# Name: revenue, dtype: int64

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso   37.000000     50     1250
# 1      Monday       Latte   37.000000     70      700
# 2     Tuesday    Espresso   36.333333     50     1500
# 3     Tuesday       Latte   35.666667     70     1400
# 4   Wednesday    Espresso   35.000000     50     1750
# 5   Wednesday       Latte   25.000000     70     1750
# 6    Thursday    Espresso   40.000000     50     2000
# 7    Thursday       Latte   30.000000     70     2100
# 8      Friday    Espresso   45.000000     50     2250
# 9      Friday       Latte   35.000000     70     2450
# 10   Saturday    Espresso   45.000000     50     2250
# 11   Saturday       Latte   35.000000     70     2450
# 12     Sunday    Espresso   45.000000     50     2250
# 13     Sunday       Latte   35.000000     70     2450

# %%
pivot=coffee.pivot(columns=['Coffee Type'],index='Day',values='revenue')

# %%
pivot
# Out:
# Coffee Type  Espresso  Latte
# Day
# Friday           2250   2450
# Monday           1250    700
# Saturday         2250   2450
# Sunday           2250   2450
# Thursday         2000   2100
# Tuesday          1500   1400
# Wednesday        1750   1750

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date height_category NOC_y born_country_full notes
# 0  1960-10-02            Tall   FRA            France   NaN
# 1         NaN         Average   FRA            France   NaN
# ...

# %%
bios['born_date']=pd.to_datetime(bios['born_date'])
bios.groupby(bios['born_date'].dt.year)['name'].count().reset_index().sort_values('name',ascending=False)
# Out:
#      born_date  name
# 139     1972.0  2231
# 152     1985.0  2227
# 140     1973.0  2216
# 138     1971.0  2205
# 137     1970.0  2174
# ..         ...   ...
# 5       1838.0     1
# 4       1837.0     1
# 3       1836.0     1
# 2       1833.0     1
# 176     2009.0     1
#
# [177 rows x 2 columns]

# %%
coffee['yester_revenue']=coffee['revenue'].shift(2)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  yester_revenue
# 0      Monday    Espresso   37.000000     50     1250             NaN
# 1      Monday       Latte   37.000000     70      700             NaN
# 2     Tuesday    Espresso   36.333333     50     1500          1250.0
# 3     Tuesday       Latte   35.666667     70     1400           700.0
# 4   Wednesday    Espresso   35.000000     50     1750          1500.0
# 5   Wednesday       Latte   25.000000     70     1750          1400.0
# 6    Thursday    Espresso   40.000000     50     2000          1750.0
# 7    Thursday       Latte   30.000000     70     2100          1750.0
# 8      Friday    Espresso   45.000000     50     2250          2000.0
# 9      Friday       Latte   35.000000     70     2450          2100.0
# 10   Saturday    Espresso   45.000000     50     2250          2250.0
# 11   Saturday       Latte   35.000000     70     2450          2450.0
# ...
