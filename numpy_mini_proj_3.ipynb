# %% [markdown]
# <a href="https://colab.research.google.com/github/bubs-art/Data-Analytics/blob/main/numpy%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
def add_mtrx(matA, matB):
  return np.add(matA,matB)

# %%
def mul_mtrx(matA,matB):
  return np.dot(matA,matB)

# %%
def det_mtrx(matA):
  return np.linalg.det(matA)

# %%
def trans_mtrx(matA):
  return np.transpose(matA)

# %%
def inverse_mtrx(matA):
  if det_mtrx(matA) ==0:
    return "inverse is not possible"
  else:
    return np.linalg.inv(matA)

# %%
def main():
  matA = np.array([[1,2],[3,4]])
  matB = np.array([[5,6],[7,8]])

  print(matA)
  print("------")
  print(matB)

  print("addition of two matrices:",add_mtrx(matA, matB))

  print("multiplication of two matrices:",mul_mtrx(matA, matB))

  print("determinant of two matrices:",det_mtrx(matA))

  print("transpose of two matrices:",trans_mtrx(matA))

  print("inverse of two matrices:",inverse_mtrx(matA))

s = main()
print(s)
# Out:
# [[1 2]
#  [3 4]]
# ------
# [[5 6]
#  [7 8]]
# addition of two matrices: [[ 6  8]
#  [10 12]]
# multiplication of two matrices: [[19 22]
#  [43 50]]
# determinant of two matrices: -2.0000000000000004
# transpose of two matrices: [[1 3]
#  [2 4]]
# inverse of two matrices: [[-2.   1. ]
#  [ 1.5 -0.5]]
# None
